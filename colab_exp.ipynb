# %% [markdown]
# # Experiments

# %% [markdown]
# ## Preparation

# %%
# !pip3 install backtesting
# Out:
# Collecting backtesting
#   Downloading Backtesting-0.3.3.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from backtesting) (1.23.5)
# Requirement already satisfied: pandas!=0.25.0,>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from backtesting) (1.5.3)
# Requirement already satisfied: bokeh>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from backtesting) (3.1.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (1.1.0)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (23.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (6.3.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (2023.7.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2022.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh>=1.4.0->backtesting) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas!=0.25.0,>=0.25.0->backtesting) (1.16.0)
# Building wheels for collected packages: backtesting
#   Building wheel for backtesting (setup.py) ... done
#   Created wheel for backtesting: filename=Backtesting-0.3.3-py3-none-any.whl size=173802 sha256=68c1df42fc15a3267a83b016fe6edefc5fc378503eaeadafa8e0578f00993a8f
#   Stored in directory: /root/.cache/pip/wheels/e2/30/7f/19cbe31987c6ebdb47f1f510343249066711609e3da2d57176
# Successfully built backtesting
# Installing collected packages: backtesting
# Successfully installed backtesting-0.3.3

# %%
# https://stackoverflow.com/questions/61362725/how-to-install-talib-module-on-google-colab-instance-using-pip
# !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/libta-lib0_0.4.0-oneiric1_amd64.deb -qO libta.deb
# !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/ta-lib0-dev_0.4.0-oneiric1_amd64.deb -qO ta.deb
# !dpkg -i libta.deb ta.deb
# !pip install ta-lib
# Out:
# Selecting previously unselected package libta-lib0.
# (Reading database ... 120511 files and directories currently installed.)
# Preparing to unpack libta.deb ...
# Unpacking libta-lib0 (0.4.0-oneiric1) ...
# Selecting previously unselected package ta-lib0-dev.
# Preparing to unpack ta.deb ...
# Unpacking ta-lib0-dev (0.4.0-oneiric1) ...
# Setting up libta-lib0 (0.4.0-oneiric1) ...
# Setting up ta-lib0-dev (0.4.0-oneiric1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# Collecting ta-lib
#   Downloading TA-Lib-0.4.27.tar.gz (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.4/266.4 kB 4.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ta-lib) (1.23.5)
# Building wheels for collected packages: ta-lib
#   Building wheel for ta-lib (pyproject.toml) ... done
#   Created wheel for ta-lib: filename=TA_Lib-0.4.27-cp310-cp310-linux_x86_64.whl size=1570190 sha256=b078d31f81218f8cf62015bd3fff697856836f6cd8a4e7c165dff4fa83570cf0
#   Stored in directory: /root/.cache/pip/wheels/cc/d2/af/ede611220f2719d334f1232aa623df38fe124a4235c9447f71
# Successfully built ta-lib
# Installing collected packages: ta-lib
# Successfully installed ta-lib-0.4.27

# %%
import os

path = "/content/drive/My Drive/Finance-Experiments"

os.chdir(path)
os.listdir(path)
# Out:
# ['datasets',
#  'MyStrategy.html',
#  '.git',
#  'models',
#  '__pycache__',
#  'ckpt',
#  'index.html',
#  'test.ipynb',
#  '.ipynb_checkpoints',
#  'test.py',
#  'ta.deb',
#  'libta.deb',
#  'requirements.txt',
#  '.gitignore',
#  'data_processor.py',
#  'colab_exp.ipynb',
#  'simulator.py',
#  'experiments.ipynb',
#  'exp_classification.py']

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import exp_classification as exp

# %% [markdown]
# ## Baseline

# %% [markdown]
# ### Random

# %%
exp.model_framework = 'Sklearn'
exp.seq_len = 1
exp.run_baseline()
# Out:
# ----------------------------------------
# Start                     2021-07-09 00:00...
# End                       2023-06-30 00:00...
# Duration                    721 days 00:00:00
# Exposure Time [%]                   99.598394
# Equity Final [$]                  9217.321048
# Equity Peak [$]                  10056.485162
# Return [%]                           -7.82679
# Buy & Hold Return [%]               35.237442
# Return (Ann.) [%]                   -4.040245
# Volatility (Ann.) [%]                3.534593
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                    -9.15715
# Avg. Drawdown [%]                    -9.15715
# Max. Drawdown Duration      716 days 00:00:00
# Avg. Drawdown Duration      716 days 00:00:00
# # Trades                                  249
# Win Rate [%]                        44.176707
# Best Trade [%]                       9.700088
# Worst Trade [%]                     -9.478757
# Avg. Trade [%]                      -0.350487
# Max. Trade Duration          14 days 00:00:00
# Avg. Trade Duration           4 days 00:00:00
# Profit Factor                        0.769003
# Expectancy [%]                      -0.301493
# SQN                                 -1.611426
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
# ----------------------------------------
# Start                     2021-07-09 00:00...
# End                       2023-06-30 00:00...
# Duration                    721 days 00:00:00
# Exposure Time [%]                   99.598394
# Equity Final [$]                 14758.315941
# Equity Peak [$]                  14758.315941
# Return [%]                          47.583159
# Buy & Hold Return [%]               35.237442
# Return (Ann.) [%]                   21.768988
# Volatility (Ann.) [%]                3.913096
# Sharpe Ratio                         5.563111
# Sortino Ratio                       13.648082
# Calmar Ratio                        25.265181
# Max. Drawdown [%]                    -0.86162
# Avg. Drawdown [%]                   -0.224383
# Max. Drawdown Duration       29 days 00:00:00
# Avg. Drawdown Duration        7 days 00:00:00
# # Trades                                  243
# Win Rate [%]                        71.604938
# Best Trade [%]                       18.08723
# Worst Trade [%]                     -5.240703
# Avg. Trade [%]                       1.633213
# Max. Trade Duration          16 days 00:00:00
# Avg. Trade Duration           4 days 00:00:00
# Profit Factor                        5.731126
# Expectancy [%]                       1.676421
# SQN                                  7.955773
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %% [markdown]
# ## Experiment 1: Logistics Regression

# %% [markdown]
# ### Sub Experiment 1 - No Technical Indicators

# %%
exp.model_framework = 'Sklearn'
exp.model_name = 'LogisticRegression'
exp.seq_len = 1
exp.max_iter = 1000
exp.technical_indicators = []

# %%
y_pred = exp.run()
# Out:
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: []
# Target: Trend
# Sequence Length: 1
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LogisticRegression
# Model Framework: Sklearn
# ----------------------------------------
# Training LogisticRegression model...
# (1812, 5) (1812,)
# Train Acc: 0.5397, Val Acc: 0.5099
# Test Acc: 0.5258, Test AUC: 0.5097
# ----------------------------------------
# Start                     2021-06-30 00:00...
# End                       2023-06-30 00:00...
# Duration                    730 days 00:00:00
# Exposure Time [%]                   99.603175
# Equity Final [$]                 10454.691581
# Equity Peak [$]                  10528.216598
# Return [%]                           4.546916
# Buy & Hold Return [%]               43.284894
# Return (Ann.) [%]                    2.248186
# Volatility (Ann.) [%]                3.669657
# Sharpe Ratio                         0.612642
# Sortino Ratio                        0.949758
# Calmar Ratio                         0.484908
# Max. Drawdown [%]                   -4.636319
# Avg. Drawdown [%]                   -0.715584
# Max. Drawdown Duration      458 days 00:00:00
# Avg. Drawdown Duration       54 days 00:00:00
# # Trades                                   76
# Win Rate [%]                        52.631579
# Best Trade [%]                      16.004629
# Worst Trade [%]                    -12.097764
# Avg. Trade [%]                       0.707052
# Max. Trade Duration          80 days 00:00:00
# Avg. Trade Duration          13 days 00:00:00
# Profit Factor                        1.623339
# Expectancy [%]                       0.811901
# SQN                                  1.153266
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %% [markdown]
# ### Sub Experiment 2 - With Technical Indicators

# %%
exp.model_framework = 'Sklearn'
exp.model_name = 'LogisticRegression'
exp.seq_len = 1
exp.max_iter = 1000
exp.technical_indicators = ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'RSI', 'RSIROCP']

# %%
y_pred = exp.run()
# Out:
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 1
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LogisticRegression
# Model Framework: Sklearn
# ----------------------------------------
# Training LogisticRegression model...
# (1792, 13) (1792,)
# Train Acc: 0.5480, Val Acc: 0.5450
# Test Acc: 0.5301, Test AUC: 0.5171
# ----------------------------------------
# Start                     2021-07-09 00:00...
# End                       2023-06-30 00:00...
# Duration                    721 days 00:00:00
# Exposure Time [%]                   99.598394
# Equity Final [$]                 10619.683874
# Equity Peak [$]                  10648.217322
# Return [%]                           6.196839
# Buy & Hold Return [%]               35.237442
# Return (Ann.) [%]                    3.089182
# Volatility (Ann.) [%]                3.568702
# Sharpe Ratio                         0.865632
# Sortino Ratio                        1.355562
# Calmar Ratio                          0.93464
# Max. Drawdown [%]                    -3.30521
# Avg. Drawdown [%]                   -0.549884
# Max. Drawdown Duration      277 days 00:00:00
# Avg. Drawdown Duration       38 days 00:00:00
# # Trades                                   77
# Win Rate [%]                        55.844156
# Best Trade [%]                      24.645457
# Worst Trade [%]                     -9.737918
# Avg. Trade [%]                       1.122434
# Max. Trade Duration         142 days 00:00:00
# Avg. Trade Duration          12 days 00:00:00
# Profit Factor                        1.962019
# Expectancy [%]                        1.26576
# SQN                                  1.457824
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %% [markdown]
# ### Sub Experiment 3 - With Technical Indicators
#
# - max_iter = 10000

# %%
exp.model_framework = 'Sklearn'
exp.model_name = 'LogisticRegression'
exp.seq_len = 1
exp.max_iter = 10000
exp.technical_indicators = ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'RSI', 'RSIROCP']

# %%
y_pred = exp.run()
# Out:
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 1
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 10000
# Model Name: LogisticRegression
# Model Framework: Sklearn
# ----------------------------------------
# Training LogisticRegression model...
# (1792, 13) (1792,)
# Train Acc: 0.5474, Val Acc: 0.5450
# Test Acc: 0.5301, Test AUC: 0.5171
# ----------------------------------------
# Start                     2021-07-09 00:00...
# End                       2023-06-30 00:00...
# Duration                    721 days 00:00:00
# Exposure Time [%]                   99.598394
# Equity Final [$]                 10619.683447
# Equity Peak [$]                  10648.216935
# Return [%]                           6.196834
# Buy & Hold Return [%]               35.237457
# Return (Ann.) [%]                     3.08918
# Volatility (Ann.) [%]                3.568701
# Sharpe Ratio                         0.865631
# Sortino Ratio                        1.355561
# Calmar Ratio                         0.934638
# Max. Drawdown [%]                   -3.305215
# Avg. Drawdown [%]                   -0.549884
# Max. Drawdown Duration      277 days 00:00:00
# Avg. Drawdown Duration       38 days 00:00:00
# # Trades                                   77
# Win Rate [%]                        55.844156
# Best Trade [%]                      24.645457
# Worst Trade [%]                     -9.737918
# Avg. Trade [%]                       1.122433
# Max. Trade Duration         142 days 00:00:00
# Avg. Trade Duration          12 days 00:00:00
# Profit Factor                        1.962017
# Expectancy [%]                       1.265759
# SQN                                  1.457822
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %% [markdown]
# ## Experiment2: LSTM

# %% [markdown]
# ### Sub Experiment 1 - No Technical Indicators

# %%
exp.model_framework = 'PyTorch'
exp.model_name = 'LSTMClassifier'
exp.seq_len = 10
exp.scale = True
exp.n_epochs = 2000
exp.technical_indicators = []
exp.input_size = 5

# %%
y_pred = exp.run()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: 10y
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: []
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# Batch Size: 32
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 1e-05
# Number of Epochs: 2000
# Max Iterations: 10000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# Epoch: 100, Train Loss: 0.6585, Train Acc: 0.5352,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 200, Train Loss: 0.6584, Train Acc: 0.5352,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 300, Train Loss: 0.6594, Train Acc: 0.5374,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 400, Train Loss: 0.6608, Train Acc: 0.5385,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 500, Train Loss: 0.6626, Train Acc: 0.5363,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 600, Train Loss: 0.6642, Train Acc: 0.5352,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 700, Train Loss: 0.6620, Train Acc: 0.5402,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 800, Train Loss: 0.6636, Train Acc: 0.5391,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 900, Train Loss: 0.6611, Train Acc: 0.5380,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1000, Train Loss: 0.6617, Train Acc: 0.5374,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1100, Train Loss: 0.6596, Train Acc: 0.5397,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1200, Train Loss: 0.6599, Train Acc: 0.5424,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1300, Train Loss: 0.6592, Train Acc: 0.5441,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1400, Train Loss: 0.6624, Train Acc: 0.5513,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1500, Train Loss: 0.6601, Train Acc: 0.5502,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1600, Train Loss: 0.6602, Train Acc: 0.5507,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1700, Train Loss: 0.6579, Train Acc: 0.5496,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1800, Train Loss: 0.6621, Train Acc: 0.5519,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1900, Train Loss: 0.6564, Train Acc: 0.5507,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 2000, Train Loss: 0.6560, Train Acc: 0.5535,                   Val Acc: 0.5130, Val AUC: 0.5000
# Test Acc: 0.5091, Test AUC: 0.4962
# ----------------------------------------
# Start                     2021-08-17 00:00...
# End                       2023-08-04 00:00...
# Duration                    717 days 00:00:00
# Exposure Time [%]                    99.59596
# Equity Final [$]                 10403.870084
# Equity Peak [$]                  10442.577448
# Return [%]                           4.038701
# Buy & Hold Return [%]               22.409772
# Return (Ann.) [%]                    2.036083
# Volatility (Ann.) [%]                2.410687
# Sharpe Ratio                         0.844607
# Sortino Ratio                        1.311335
# Calmar Ratio                         0.914729
# Max. Drawdown [%]                   -2.225886
# Avg. Drawdown [%]                   -0.847615
# Max. Drawdown Duration      602 days 00:00:00
# Avg. Drawdown Duration      100 days 00:00:00
# # Trades                                    4
# Win Rate [%]                             75.0
# Best Trade [%]                      22.039906
# Worst Trade [%]                     -1.547042
# Avg. Trade [%]                      10.948659
# Max. Trade Duration         582 days 00:00:00
# Avg. Trade Duration         211 days 00:00:00
# Profit Factor                       30.568613
# Expectancy [%]                      11.435972
# SQN                                  1.543213
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                      Size  EntryBa...
# dtype: object

# %% [markdown]
# ### Sub Experiment 2 - With Technical Indicators

# %%
exp.model_framework = 'PyTorch'
exp.model_name = 'LSTMClassifier'
exp.seq_len = 10
exp.period = None
exp.n_epochs = 1000
exp.hidden_size = 64
exp.batch_size = 512
exp.technical_indicators = ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']

# %%
for _ in range(20):
    y_pred = exp.run()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5739, Train Acc: 0.6708,             Val Acc: 0.4974, Val AUC: 0.5002, lr: 0.001000
# Epoch: 200, Train Loss: 0.2942, Train Acc: 0.8575,             Val Acc: 0.4869, Val AUC: 0.4869, lr: 0.001000
# Epoch: 300, Train Loss: 0.1315, Train Acc: 0.9635,             Val Acc: 0.4921, Val AUC: 0.4908, lr: 0.001000
# Epoch: 400, Train Loss: 0.0625, Train Acc: 0.9877,             Val Acc: 0.4764, Val AUC: 0.4748, lr: 0.001000
# Epoch: 500, Train Loss: 0.0387, Train Acc: 0.9944,             Val Acc: 0.4921, Val AUC: 0.4900, lr: 0.001000
# Epoch: 600, Train Loss: 0.0195, Train Acc: 0.9994,             Val Acc: 0.4712, Val AUC: 0.4693, lr: 0.001000
# Epoch: 700, Train Loss: 0.0199, Train Acc: 0.9989,             Val Acc: 0.4503, Val AUC: 0.4479, lr: 0.001000
# Epoch: 800, Train Loss: 0.0080, Train Acc: 1.0000,             Val Acc: 0.4869, Val AUC: 0.4835, lr: 0.001000
# Epoch: 900, Train Loss: 0.0045, Train Acc: 1.0000,             Val Acc: 0.4869, Val AUC: 0.4832, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0077, Train Acc: 0.9994,             Val Acc: 0.4764, Val AUC: 0.4733, lr: 0.001000
# Test Acc: 0.5276, Test AUC: 0.5257
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10502.635025
# Equity Peak [$]                  10785.302805
# Return [%]                            5.02635
# Buy & Hold Return [%]               33.680567
# Return (Ann.) [%]                    2.559477
# Volatility (Ann.) [%]                3.714446
# Sharpe Ratio                          0.68906
# Sortino Ratio                        1.030655
# Calmar Ratio                         0.839076
# Max. Drawdown [%]                   -3.050353
# Avg. Drawdown [%]                   -0.627109
# Max. Drawdown Duration      141 days 00:00:00
# Avg. Drawdown Duration       24 days 00:00:00
# # Trades                                  150
# Win Rate [%]                        52.666667
# Best Trade [%]                      10.193823
# Worst Trade [%]                     -7.824687
# Avg. Trade [%]                       0.137289
# Max. Trade Duration          28 days 00:00:00
# Avg. Trade Duration           6 days 00:00:00
# Profit Factor                        1.154505
# Expectancy [%]                       0.198799
# SQN                                  1.153719
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5861, Train Acc: 0.6769,             Val Acc: 0.5079, Val AUC: 0.5033, lr: 0.001000
# Epoch: 200, Train Loss: 0.2981, Train Acc: 0.8312,             Val Acc: 0.5602, Val AUC: 0.5576, lr: 0.001000
# Epoch: 300, Train Loss: 0.1099, Train Acc: 0.9232,             Val Acc: 0.5079, Val AUC: 0.5023, lr: 0.001000
# Epoch: 400, Train Loss: 0.0530, Train Acc: 0.9753,             Val Acc: 0.5393, Val AUC: 0.5352, lr: 0.001000
# Epoch: 500, Train Loss: 0.0222, Train Acc: 0.9888,             Val Acc: 0.5183, Val AUC: 0.5121, lr: 0.001000
# Epoch: 600, Train Loss: 0.0081, Train Acc: 0.9972,             Val Acc: 0.5079, Val AUC: 0.5010, lr: 0.001000
# Epoch: 700, Train Loss: 0.0222, Train Acc: 0.9983,             Val Acc: 0.5183, Val AUC: 0.5124, lr: 0.001000
# Epoch: 800, Train Loss: 0.0061, Train Acc: 0.9994,             Val Acc: 0.4869, Val AUC: 0.4800, lr: 0.001000
# Epoch: 900, Train Loss: 0.0031, Train Acc: 0.9994,             Val Acc: 0.4921, Val AUC: 0.4859, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0051, Train Acc: 0.9994,             Val Acc: 0.5183, Val AUC: 0.5120, lr: 0.001000
# Test Acc: 0.5031, Test AUC: 0.5060
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10260.018055
# Equity Peak [$]                   10742.40868
# Return [%]                           2.600181
# Buy & Hold Return [%]               33.680553
# Return (Ann.) [%]                    1.331634
# Volatility (Ann.) [%]                3.994731
# Sharpe Ratio                         0.333348
# Sortino Ratio                        0.505817
# Calmar Ratio                         0.296543
# Max. Drawdown [%]                   -4.490526
# Avg. Drawdown [%]                   -0.817092
# Max. Drawdown Duration      207 days 00:00:00
# Avg. Drawdown Duration       37 days 00:00:00
# # Trades                                   91
# Win Rate [%]                        59.340659
# Best Trade [%]                       8.819635
# Worst Trade [%]                    -15.970816
# Avg. Trade [%]                        0.62948
# Max. Trade Duration          72 days 00:00:00
# Avg. Trade Duration          11 days 00:00:00
# Profit Factor                        1.583116
# Expectancy [%]                       0.713054
# SQN                                  0.534007
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5559, Train Acc: 0.6921,             Val Acc: 0.5393, Val AUC: 0.5336, lr: 0.001000
# Epoch: 200, Train Loss: 0.3040, Train Acc: 0.8861,             Val Acc: 0.5131, Val AUC: 0.5061, lr: 0.001000
# Epoch: 300, Train Loss: 0.0961, Train Acc: 0.9792,             Val Acc: 0.5288, Val AUC: 0.5221, lr: 0.001000
# Epoch: 400, Train Loss: 0.0452, Train Acc: 0.9933,             Val Acc: 0.5183, Val AUC: 0.5115, lr: 0.001000
# Epoch: 500, Train Loss: 0.0243, Train Acc: 0.9994,             Val Acc: 0.5183, Val AUC: 0.5115, lr: 0.001000
# Epoch: 600, Train Loss: 0.0120, Train Acc: 1.0000,             Val Acc: 0.5183, Val AUC: 0.5111, lr: 0.001000
# Epoch: 700, Train Loss: 0.0090, Train Acc: 1.0000,             Val Acc: 0.5183, Val AUC: 0.5113, lr: 0.001000
# Epoch: 800, Train Loss: 0.0055, Train Acc: 1.0000,             Val Acc: 0.5183, Val AUC: 0.5113, lr: 0.001000
# Epoch: 900, Train Loss: 0.0190, Train Acc: 0.9994,             Val Acc: 0.5759, Val AUC: 0.5708, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0080, Train Acc: 0.9983,             Val Acc: 0.5550, Val AUC: 0.5500, lr: 0.001000
# Test Acc: 0.5378, Test AUC: 0.5366
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10511.424179
# Equity Peak [$]                  10971.150492
# Return [%]                           5.114242
# Buy & Hold Return [%]               33.680553
# Return (Ann.) [%]                    2.603698
# Volatility (Ann.) [%]                3.981642
# Sharpe Ratio                         0.653926
# Sortino Ratio                        1.011648
# Calmar Ratio                          0.62136
# Max. Drawdown [%]                    -4.19032
# Avg. Drawdown [%]                    -0.57949
# Max. Drawdown Duration      291 days 00:00:00
# Avg. Drawdown Duration       28 days 00:00:00
# # Trades                                   87
# Win Rate [%]                        56.321839
# Best Trade [%]                      12.400245
# Worst Trade [%]                     -9.218918
# Avg. Trade [%]                       0.436797
# Max. Trade Duration          55 days 00:00:00
# Avg. Trade Duration          11 days 00:00:00
# Profit Factor                        1.427627
# Expectancy [%]                       0.517934
# SQN                                  1.162868
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.4986, Train Acc: 0.7039,             Val Acc: 0.5183, Val AUC: 0.5128, lr: 0.001000
# Epoch: 200, Train Loss: 0.1966, Train Acc: 0.8564,             Val Acc: 0.4817, Val AUC: 0.4783, lr: 0.001000
# Epoch: 300, Train Loss: 0.0487, Train Acc: 0.9495,             Val Acc: 0.4869, Val AUC: 0.4879, lr: 0.001000
# Epoch: 400, Train Loss: 0.0162, Train Acc: 0.9849,             Val Acc: 0.4869, Val AUC: 0.4879, lr: 0.001000
# Epoch: 500, Train Loss: 0.0083, Train Acc: 0.9978,             Val Acc: 0.4555, Val AUC: 0.4577, lr: 0.001000
# Epoch: 600, Train Loss: 0.0246, Train Acc: 0.9966,             Val Acc: 0.4660, Val AUC: 0.4680, lr: 0.001000
# Epoch: 700, Train Loss: 0.0030, Train Acc: 0.9989,             Val Acc: 0.4450, Val AUC: 0.4482, lr: 0.001000
# Epoch: 800, Train Loss: 0.0021, Train Acc: 1.0000,             Val Acc: 0.4607, Val AUC: 0.4643, lr: 0.001000
# Epoch: 900, Train Loss: 0.0013, Train Acc: 1.0000,             Val Acc: 0.4660, Val AUC: 0.4699, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0070, Train Acc: 1.0000,             Val Acc: 0.4764, Val AUC: 0.4796, lr: 0.001000
# Test Acc: 0.5276, Test AUC: 0.5406
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10182.031081
# Equity Peak [$]                  10593.537757
# Return [%]                           1.820311
# Buy & Hold Return [%]               33.680553
# Return (Ann.) [%]                    0.933973
# Volatility (Ann.) [%]                4.307146
# Sharpe Ratio                         0.216843
# Sortino Ratio                        0.322197
# Calmar Ratio                         0.239705
# Max. Drawdown [%]                   -3.896344
# Avg. Drawdown [%]                   -0.940018
# Max. Drawdown Duration      206 days 00:00:00
# Avg. Drawdown Duration       37 days 00:00:00
# # Trades                                   60
# Win Rate [%]                        66.666667
# Best Trade [%]                      11.594879
# Worst Trade [%]                    -20.219845
# Avg. Trade [%]                       0.117638
# Max. Trade Duration         100 days 00:00:00
# Avg. Trade Duration          17 days 00:00:00
# Profit Factor                        1.163257
# Expectancy [%]                       0.247239
# SQN                                  0.399764
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5683, Train Acc: 0.6870,             Val Acc: 0.4764, Val AUC: 0.4803, lr: 0.001000
# Epoch: 200, Train Loss: 0.2859, Train Acc: 0.8682,             Val Acc: 0.5026, Val AUC: 0.5065, lr: 0.001000
# Epoch: 300, Train Loss: 0.1153, Train Acc: 0.9736,             Val Acc: 0.4712, Val AUC: 0.4744, lr: 0.001000
# Epoch: 400, Train Loss: 0.1735, Train Acc: 0.9781,             Val Acc: 0.5288, Val AUC: 0.5313, lr: 0.001000
# Epoch: 500, Train Loss: 0.0193, Train Acc: 0.9978,             Val Acc: 0.5445, Val AUC: 0.5453, lr: 0.001000
# Epoch: 600, Train Loss: 0.0713, Train Acc: 0.9983,             Val Acc: 0.4712, Val AUC: 0.4715, lr: 0.001000
# Epoch: 700, Train Loss: 0.3143, Train Acc: 0.9731,             Val Acc: 0.4764, Val AUC: 0.4770, lr: 0.001000
# Epoch: 800, Train Loss: 0.0089, Train Acc: 1.0000,             Val Acc: 0.4712, Val AUC: 0.4703, lr: 0.001000
# Epoch: 900, Train Loss: 0.0051, Train Acc: 1.0000,             Val Acc: 0.4921, Val AUC: 0.4916, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0035, Train Acc: 0.9961,             Val Acc: 0.4974, Val AUC: 0.4973, lr: 0.001000
# Test Acc: 0.5031, Test AUC: 0.5175
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10085.383226
# Equity Peak [$]                  10597.111162
# Return [%]                           0.853832
# Buy & Hold Return [%]               33.680553
# Return (Ann.) [%]                    0.439105
# Volatility (Ann.) [%]                3.575283
# Sharpe Ratio                         0.122817
# Sortino Ratio                        0.183954
# Calmar Ratio                         0.090932
# Max. Drawdown [%]                   -4.828938
# Avg. Drawdown [%]                   -0.971763
# Max. Drawdown Duration      219 days 00:00:00
# Avg. Drawdown Duration       37 days 00:00:00
# # Trades                                   32
# Win Rate [%]                            56.25
# Best Trade [%]                      14.852322
# Worst Trade [%]                    -25.255439
# Avg. Trade [%]                       0.391486
# Max. Trade Duration         134 days 00:00:00
# Avg. Trade Duration          28 days 00:00:00
# Profit Factor                        1.296954
# Expectancy [%]                       0.734222
# SQN                                  0.138938
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5422, Train Acc: 0.7067,             Val Acc: 0.5236, Val AUC: 0.5197, lr: 0.001000
# Epoch: 200, Train Loss: 0.3537, Train Acc: 0.8766,             Val Acc: 0.5864, Val AUC: 0.5824, lr: 0.001000
# Epoch: 300, Train Loss: 0.2061, Train Acc: 0.9708,             Val Acc: 0.5497, Val AUC: 0.5447, lr: 0.001000
# Epoch: 400, Train Loss: 0.1033, Train Acc: 0.9893,             Val Acc: 0.5602, Val AUC: 0.5557, lr: 0.001000
# Epoch: 500, Train Loss: 0.0458, Train Acc: 0.9961,             Val Acc: 0.5445, Val AUC: 0.5402, lr: 0.001000
# Epoch: 600, Train Loss: 0.0211, Train Acc: 0.9989,             Val Acc: 0.5131, Val AUC: 0.5083, lr: 0.001000
# Epoch: 700, Train Loss: 0.0129, Train Acc: 1.0000,             Val Acc: 0.5183, Val AUC: 0.5139, lr: 0.001000
# Epoch: 800, Train Loss: 0.0140, Train Acc: 1.0000,             Val Acc: 0.5236, Val AUC: 0.5186, lr: 0.001000
# Epoch: 900, Train Loss: 0.0069, Train Acc: 1.0000,             Val Acc: 0.5236, Val AUC: 0.5189, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0050, Train Acc: 1.0000,             Val Acc: 0.5079, Val AUC: 0.5031, lr: 0.001000
# Test Acc: 0.5399, Test AUC: 0.5365
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                  9992.621297
# Equity Peak [$]                  10211.862193
# Return [%]                          -0.073787
# Buy & Hold Return [%]               33.680539
# Return (Ann.) [%]                   -0.038032
# Volatility (Ann.) [%]                4.420926
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                   -4.403932
# Avg. Drawdown [%]                   -1.121326
# Max. Drawdown Duration      420 days 00:00:00
# Avg. Drawdown Duration       70 days 00:00:00
# # Trades                                   96
# Win Rate [%]                             62.5
# Best Trade [%]                      11.538665
# Worst Trade [%]                    -10.417562
# Avg. Trade [%]                       0.237623
# Max. Trade Duration          45 days 00:00:00
# Avg. Trade Duration          10 days 00:00:00
# Profit Factor                        1.229692
# Expectancy [%]                        0.31572
# SQN                                 -0.017814
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5061, Train Acc: 0.6915,             Val Acc: 0.4974, Val AUC: 0.4903, lr: 0.001000
# Epoch: 200, Train Loss: 0.1962, Train Acc: 0.8901,             Val Acc: 0.5079, Val AUC: 0.5018, lr: 0.001000
# Epoch: 300, Train Loss: 0.0572, Train Acc: 0.9647,             Val Acc: 0.5131, Val AUC: 0.5071, lr: 0.001000
# Epoch: 400, Train Loss: 0.0183, Train Acc: 0.9865,             Val Acc: 0.5236, Val AUC: 0.5179, lr: 0.001000
# Epoch: 500, Train Loss: 0.0146, Train Acc: 0.9972,             Val Acc: 0.5550, Val AUC: 0.5505, lr: 0.001000
# Epoch: 600, Train Loss: 0.0055, Train Acc: 0.9989,             Val Acc: 0.5393, Val AUC: 0.5349, lr: 0.001000
# Epoch: 700, Train Loss: 0.0113, Train Acc: 1.0000,             Val Acc: 0.5236, Val AUC: 0.5184, lr: 0.001000
# Epoch: 800, Train Loss: 0.0031, Train Acc: 1.0000,             Val Acc: 0.5340, Val AUC: 0.5294, lr: 0.001000
# Epoch: 900, Train Loss: 0.0020, Train Acc: 1.0000,             Val Acc: 0.5393, Val AUC: 0.5347, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0014, Train Acc: 1.0000,             Val Acc: 0.5393, Val AUC: 0.5349, lr: 0.001000
# Test Acc: 0.5378, Test AUC: 0.5366
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10280.804998
# Equity Peak [$]                  10577.504434
# Return [%]                            2.80805
# Buy & Hold Return [%]               33.680567
# Return (Ann.) [%]                    1.437381
# Volatility (Ann.) [%]                4.174678
# Sharpe Ratio                         0.344309
# Sortino Ratio                        0.491381
# Calmar Ratio                          0.38659
# Max. Drawdown [%]                   -3.718101
# Avg. Drawdown [%]                   -0.820113
# Max. Drawdown Duration      224 days 00:00:00
# Avg. Drawdown Duration       32 days 00:00:00
# # Trades                                   64
# Win Rate [%]                          64.0625
# Best Trade [%]                      13.699588
# Worst Trade [%]                    -21.719075
# Avg. Trade [%]                       0.296397
# Max. Trade Duration          94 days 00:00:00
# Avg. Trade Duration          15 days 00:00:00
# Profit Factor                        1.273881
# Expectancy [%]                       0.441576
# SQN                                  0.613749
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.4934, Train Acc: 0.7005,             Val Acc: 0.5079, Val AUC: 0.5000, lr: 0.001000
# Epoch: 200, Train Loss: 0.2028, Train Acc: 0.8811,             Val Acc: 0.5079, Val AUC: 0.5000, lr: 0.001000
# Epoch: 300, Train Loss: 0.0614, Train Acc: 0.9602,             Val Acc: 0.5079, Val AUC: 0.5000, lr: 0.001000
# Epoch: 400, Train Loss: 0.0238, Train Acc: 0.9865,             Val Acc: 0.5079, Val AUC: 0.5000, lr: 0.001000
# Epoch: 500, Train Loss: 0.0108, Train Acc: 0.9978,             Val Acc: 0.5131, Val AUC: 0.5053, lr: 0.001000
# Epoch: 600, Train Loss: 0.2063, Train Acc: 0.9635,             Val Acc: 0.5079, Val AUC: 0.5002, lr: 0.001000
# Epoch: 700, Train Loss: 0.0046, Train Acc: 1.0000,             Val Acc: 0.5079, Val AUC: 0.5000, lr: 0.001000
# Epoch: 800, Train Loss: 0.0026, Train Acc: 1.0000,             Val Acc: 0.5079, Val AUC: 0.5000, lr: 0.001000
# Epoch: 900, Train Loss: 0.0032, Train Acc: 1.0000,             Val Acc: 0.5079, Val AUC: 0.5000, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0019, Train Acc: 1.0000,             Val Acc: 0.5079, Val AUC: 0.5000, lr: 0.001000
# Test Acc: 0.5133, Test AUC: 0.4973
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10650.614296
# Equity Peak [$]                  10650.614296
# Return [%]                           6.506143
# Buy & Hold Return [%]               33.680567
# Return (Ann.) [%]                    3.301633
# Volatility (Ann.) [%]                3.131813
# Sharpe Ratio                         1.054224
# Sortino Ratio                        1.713931
# Calmar Ratio                         1.055635
# Max. Drawdown [%]                   -3.127626
# Avg. Drawdown [%]                   -0.612508
# Max. Drawdown Duration      496 days 00:00:00
# Avg. Drawdown Duration       40 days 00:00:00
# # Trades                                   21
# Win Rate [%]                        47.619048
# Best Trade [%]                      27.504692
# Worst Trade [%]                    -14.659525
# Avg. Trade [%]                       1.948434
# Max. Trade Duration         141 days 00:00:00
# Avg. Trade Duration          41 days 00:00:00
# Profit Factor                         2.38463
# Expectancy [%]                       2.387155
# SQN                                  1.131982
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5165, Train Acc: 0.6949,             Val Acc: 0.5026, Val AUC: 0.5046, lr: 0.001000
# Epoch: 200, Train Loss: 0.2494, Train Acc: 0.8345,             Val Acc: 0.4921, Val AUC: 0.4977, lr: 0.001000
# Epoch: 300, Train Loss: 0.1170, Train Acc: 0.9546,             Val Acc: 0.5340, Val AUC: 0.5371, lr: 0.001000
# Epoch: 400, Train Loss: 0.0334, Train Acc: 0.9921,             Val Acc: 0.5236, Val AUC: 0.5270, lr: 0.001000
# Epoch: 500, Train Loss: 0.0529, Train Acc: 0.9978,             Val Acc: 0.5079, Val AUC: 0.5099, lr: 0.001000
# Epoch: 600, Train Loss: 0.0138, Train Acc: 0.9989,             Val Acc: 0.5288, Val AUC: 0.5315, lr: 0.001000
# Epoch: 700, Train Loss: 0.0061, Train Acc: 1.0000,             Val Acc: 0.5340, Val AUC: 0.5371, lr: 0.001000
# Epoch: 800, Train Loss: 0.0159, Train Acc: 1.0000,             Val Acc: 0.4921, Val AUC: 0.4967, lr: 0.001000
# Epoch: 900, Train Loss: 0.0284, Train Acc: 0.9961,             Val Acc: 0.4921, Val AUC: 0.4970, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0027, Train Acc: 1.0000,             Val Acc: 0.5288, Val AUC: 0.5323, lr: 0.001000
# Test Acc: 0.5010, Test AUC: 0.5102
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10390.912334
# Equity Peak [$]                  10561.714275
# Return [%]                           3.909123
# Buy & Hold Return [%]               33.680539
# Return (Ann.) [%]                    1.995794
# Volatility (Ann.) [%]                3.919866
# Sharpe Ratio                         0.509149
# Sortino Ratio                        0.787701
# Calmar Ratio                         0.518675
# Max. Drawdown [%]                   -3.847869
# Avg. Drawdown [%]                   -0.983795
# Max. Drawdown Duration      184 days 00:00:00
# Avg. Drawdown Duration       41 days 00:00:00
# # Trades                                   51
# Win Rate [%]                        60.784314
# Best Trade [%]                       8.257705
# Worst Trade [%]                    -25.027394
# Avg. Trade [%]                      -0.247136
# Max. Trade Duration         116 days 00:00:00
# Avg. Trade Duration          18 days 00:00:00
# Profit Factor                        0.986312
# Expectancy [%]                      -0.030139
# SQN                                  1.091391
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.4519, Train Acc: 0.7156,             Val Acc: 0.5079, Val AUC: 0.5000, lr: 0.001000
# Epoch: 200, Train Loss: 0.1518, Train Acc: 0.8867,             Val Acc: 0.5026, Val AUC: 0.4948, lr: 0.001000
# Epoch: 300, Train Loss: 0.1861, Train Acc: 0.9170,             Val Acc: 0.5131, Val AUC: 0.5053, lr: 0.001000
# Epoch: 400, Train Loss: 0.0283, Train Acc: 0.9893,             Val Acc: 0.5079, Val AUC: 0.5003, lr: 0.001000
# Epoch: 500, Train Loss: 0.0120, Train Acc: 0.9966,             Val Acc: 0.5288, Val AUC: 0.5218, lr: 0.001000
# Epoch: 600, Train Loss: 0.0053, Train Acc: 0.9989,             Val Acc: 0.5131, Val AUC: 0.5061, lr: 0.001000
# Epoch: 700, Train Loss: 0.0072, Train Acc: 1.0000,             Val Acc: 0.5236, Val AUC: 0.5166, lr: 0.001000
# Epoch: 800, Train Loss: 0.0032, Train Acc: 1.0000,             Val Acc: 0.5079, Val AUC: 0.5010, lr: 0.001000
# Epoch: 900, Train Loss: 0.0023, Train Acc: 1.0000,             Val Acc: 0.5026, Val AUC: 0.4957, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0041, Train Acc: 1.0000,             Val Acc: 0.4921, Val AUC: 0.4863, lr: 0.001000
# Test Acc: 0.5112, Test AUC: 0.5046
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10098.523155
# Equity Peak [$]                  10203.954037
# Return [%]                           0.985232
# Buy & Hold Return [%]               33.680553
# Return (Ann.) [%]                     0.50652
# Volatility (Ann.) [%]                3.278474
# Sharpe Ratio                         0.154499
# Sortino Ratio                        0.224487
# Calmar Ratio                         0.165806
# Max. Drawdown [%]                   -3.054893
# Avg. Drawdown [%]                   -0.817778
# Max. Drawdown Duration      210 days 00:00:00
# Avg. Drawdown Duration       58 days 00:00:00
# # Trades                                   83
# Win Rate [%]                         50.60241
# Best Trade [%]                      11.304608
# Worst Trade [%]                    -11.131439
# Avg. Trade [%]                      -0.141344
# Max. Trade Duration          89 days 00:00:00
# Avg. Trade Duration          11 days 00:00:00
# Profit Factor                        0.940466
# Expectancy [%]                      -0.077642
# SQN                                  0.331738
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.4943, Train Acc: 0.7072,             Val Acc: 0.4974, Val AUC: 0.4959, lr: 0.001000
# Epoch: 200, Train Loss: 0.2277, Train Acc: 0.8946,             Val Acc: 0.5288, Val AUC: 0.5270, lr: 0.001000
# Epoch: 300, Train Loss: 0.0856, Train Acc: 0.9725,             Val Acc: 0.5026, Val AUC: 0.4999, lr: 0.001000
# Epoch: 400, Train Loss: 0.0436, Train Acc: 0.9910,             Val Acc: 0.5131, Val AUC: 0.5099, lr: 0.001000
# Epoch: 500, Train Loss: 0.0199, Train Acc: 0.9978,             Val Acc: 0.5079, Val AUC: 0.5043, lr: 0.001000
# Epoch: 600, Train Loss: 0.0145, Train Acc: 0.9994,             Val Acc: 0.4869, Val AUC: 0.4840, lr: 0.001000
# Epoch: 700, Train Loss: 0.0080, Train Acc: 1.0000,             Val Acc: 0.5079, Val AUC: 0.5046, lr: 0.001000
# Epoch: 800, Train Loss: 0.0115, Train Acc: 1.0000,             Val Acc: 0.5079, Val AUC: 0.5054, lr: 0.001000
# Epoch: 900, Train Loss: 0.0052, Train Acc: 1.0000,             Val Acc: 0.4974, Val AUC: 0.4946, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0029, Train Acc: 1.0000,             Val Acc: 0.5079, Val AUC: 0.5051, lr: 0.001000
# Test Acc: 0.5174, Test AUC: 0.5060
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                  9999.930698
# Equity Peak [$]                  10452.759576
# Return [%]                          -0.000693
# Buy & Hold Return [%]               33.680539
# Return (Ann.) [%]                   -0.000357
# Volatility (Ann.) [%]                 3.43983
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                   -5.978075
# Avg. Drawdown [%]                   -1.086773
# Max. Drawdown Duration      458 days 00:00:00
# Avg. Drawdown Duration       57 days 00:00:00
# # Trades                                   51
# Win Rate [%]                        50.980392
# Best Trade [%]                      19.914919
# Worst Trade [%]                    -16.061386
# Avg. Trade [%]                       0.147431
# Max. Trade Duration          94 days 00:00:00
# Avg. Trade Duration          18 days 00:00:00
# Profit Factor                        1.175604
# Expectancy [%]                       0.309081
# SQN                                  0.066496
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5477, Train Acc: 0.6663,             Val Acc: 0.5236, Val AUC: 0.5271, lr: 0.001000
# Epoch: 200, Train Loss: 0.3016, Train Acc: 0.8525,             Val Acc: 0.4660, Val AUC: 0.4665, lr: 0.001000
# Epoch: 300, Train Loss: 0.1081, Train Acc: 0.9585,             Val Acc: 0.4974, Val AUC: 0.4966, lr: 0.001000
# Epoch: 400, Train Loss: 0.0489, Train Acc: 0.9882,             Val Acc: 0.5236, Val AUC: 0.5207, lr: 0.001000
# Epoch: 500, Train Loss: 0.0231, Train Acc: 0.9966,             Val Acc: 0.4869, Val AUC: 0.4832, lr: 0.001000
# Epoch: 600, Train Loss: 0.0125, Train Acc: 0.9989,             Val Acc: 0.4921, Val AUC: 0.4883, lr: 0.001000
# Epoch: 700, Train Loss: 0.0062, Train Acc: 0.9989,             Val Acc: 0.4974, Val AUC: 0.4933, lr: 0.001000
# Epoch: 800, Train Loss: 0.0041, Train Acc: 0.9994,             Val Acc: 0.4921, Val AUC: 0.4883, lr: 0.001000
# Epoch: 900, Train Loss: 0.2105, Train Acc: 0.9282,             Val Acc: 0.5497, Val AUC: 0.5449, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0069, Train Acc: 1.0000,             Val Acc: 0.5236, Val AUC: 0.5183, lr: 0.001000
# Test Acc: 0.4969, Test AUC: 0.4940
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                  10855.50636
# Equity Peak [$]                  11133.406403
# Return [%]                           8.555064
# Buy & Hold Return [%]               33.680553
# Return (Ann.) [%]                     4.32102
# Volatility (Ann.) [%]                4.076012
# Sharpe Ratio                          1.06011
# Sortino Ratio                        1.837032
# Calmar Ratio                         1.374578
# Max. Drawdown [%]                   -3.143524
# Avg. Drawdown [%]                   -0.582632
# Max. Drawdown Duration      164 days 00:00:00
# Avg. Drawdown Duration       26 days 00:00:00
# # Trades                                  137
# Win Rate [%]                        56.934307
# Best Trade [%]                      18.600279
# Worst Trade [%]                    -11.622257
# Avg. Trade [%]                       0.489255
# Max. Trade Duration          43 days 00:00:00
# Avg. Trade Duration           7 days 00:00:00
# Profit Factor                        1.542844
# Expectancy [%]                       0.558656
# SQN                                  1.730508
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5007, Train Acc: 0.7011,             Val Acc: 0.4921, Val AUC: 0.4878, lr: 0.001000
# Epoch: 200, Train Loss: 0.3547, Train Acc: 0.8121,             Val Acc: 0.5340, Val AUC: 0.5276, lr: 0.001000
# Epoch: 300, Train Loss: 0.1091, Train Acc: 0.9260,             Val Acc: 0.4974, Val AUC: 0.4903, lr: 0.001000
# Epoch: 400, Train Loss: 0.0798, Train Acc: 0.9714,             Val Acc: 0.5183, Val AUC: 0.5111, lr: 0.001000
# Epoch: 500, Train Loss: 0.0352, Train Acc: 0.9854,             Val Acc: 0.5131, Val AUC: 0.5056, lr: 0.001000
# Epoch: 600, Train Loss: 0.0622, Train Acc: 0.9933,             Val Acc: 0.5026, Val AUC: 0.4952, lr: 0.001000
# Epoch: 700, Train Loss: 0.0156, Train Acc: 0.9983,             Val Acc: 0.5079, Val AUC: 0.5003, lr: 0.001000
# Epoch: 800, Train Loss: 0.0107, Train Acc: 1.0000,             Val Acc: 0.5131, Val AUC: 0.5055, lr: 0.001000
# Epoch: 900, Train Loss: 0.0088, Train Acc: 1.0000,             Val Acc: 0.5288, Val AUC: 0.5213, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0045, Train Acc: 1.0000,             Val Acc: 0.5131, Val AUC: 0.5053, lr: 0.001000
# Test Acc: 0.5133, Test AUC: 0.4989
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10402.484646
# Equity Peak [$]                  10513.285335
# Return [%]                           4.024846
# Buy & Hold Return [%]               33.680567
# Return (Ann.) [%]                    2.054317
# Volatility (Ann.) [%]                 3.57093
# Sharpe Ratio                         0.575289
# Sortino Ratio                        0.835327
# Calmar Ratio                         0.443616
# Max. Drawdown [%]                   -4.630849
# Avg. Drawdown [%]                    -0.66461
# Max. Drawdown Duration      361 days 00:00:00
# Avg. Drawdown Duration       34 days 00:00:00
# # Trades                                   17
# Win Rate [%]                        76.470588
# Best Trade [%]                      18.203622
# Worst Trade [%]                    -11.558938
# Avg. Trade [%]                       2.732761
# Max. Trade Duration         164 days 00:00:00
# Avg. Trade Duration          55 days 00:00:00
# Profit Factor                        2.790801
# Expectancy [%]                       3.026336
# SQN                                  1.215363
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# ...
# Test Acc: 0.5031, Test AUC: 0.5050
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10377.544265
# Equity Peak [$]                  10693.203115
# Return [%]                           3.775443
# Buy & Hold Return [%]               33.680567
# Return (Ann.) [%]                    1.928151
# Volatility (Ann.) [%]                 4.16643
# Sharpe Ratio                         0.462783
# Sortino Ratio                        0.700347
# Calmar Ratio                         0.532149
# Max. Drawdown [%]                   -3.623327
# Avg. Drawdown [%]                   -0.933083
# Max. Drawdown Duration      273 days 00:00:00
# Avg. Drawdown Duration       43 days 00:00:00
# # Trades                                  135
# Win Rate [%]                         50.37037
# Best Trade [%]                      10.394234
# Worst Trade [%]                    -11.717861
# Avg. Trade [%]                      -0.085059
# Max. Trade Duration          42 days 00:00:00
# Avg. Trade Duration           7 days 00:00:00
# Profit Factor                          0.9867
# Expectancy [%]                      -0.018218
# SQN                                  0.836414
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.4518, Train Acc: 0.7151,             Val Acc: 0.5079, Val AUC: 0.5002, lr: 0.001000
# Epoch: 200, Train Loss: 0.1710, Train Acc: 0.8867,             Val Acc: 0.5026, Val AUC: 0.4970, lr: 0.001000
# Epoch: 300, Train Loss: 0.0537, Train Acc: 0.9647,             Val Acc: 0.5393, Val AUC: 0.5349, lr: 0.001000
# Epoch: 400, Train Loss: 0.0210, Train Acc: 0.9860,             Val Acc: 0.5550, Val AUC: 0.5521, lr: 0.001000
# Epoch: 500, Train Loss: 0.0099, Train Acc: 0.9933,             Val Acc: 0.5236, Val AUC: 0.5217, lr: 0.001000
# Epoch: 600, Train Loss: 0.0041, Train Acc: 0.9961,             Val Acc: 0.5236, Val AUC: 0.5222, lr: 0.001000
# Epoch: 700, Train Loss: 0.0022, Train Acc: 0.9978,             Val Acc: 0.5340, Val AUC: 0.5328, lr: 0.001000
# Epoch: 800, Train Loss: 0.0012, Train Acc: 0.9989,             Val Acc: 0.5236, Val AUC: 0.5224, lr: 0.001000
# Epoch: 900, Train Loss: 0.0008, Train Acc: 0.9989,             Val Acc: 0.5236, Val AUC: 0.5224, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0686, Train Acc: 0.9989,             Val Acc: 0.5445, Val AUC: 0.5400, lr: 0.001000
# Test Acc: 0.5174, Test AUC: 0.5125
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10076.042151
# Equity Peak [$]                  10170.763488
# Return [%]                           0.760422
# Buy & Hold Return [%]               33.680567
# Return (Ann.) [%]                    0.391154
# Volatility (Ann.) [%]                4.431914
# Sharpe Ratio                         0.088259
# Sortino Ratio                        0.132266
# Calmar Ratio                         0.059665
# Max. Drawdown [%]                   -6.555793
# Avg. Drawdown [%]                   -1.256837
# Max. Drawdown Duration      661 days 00:00:00
# Avg. Drawdown Duration      116 days 00:00:00
# # Trades                                   78
# Win Rate [%]                        52.564103
# Best Trade [%]                      12.562541
# Worst Trade [%]                    -13.721205
# Avg. Trade [%]                      -0.024039
# Max. Trade Duration          71 days 00:00:00
# Avg. Trade Duration          11 days 00:00:00
# Profit Factor                        1.045682
# Expectancy [%]                       0.075027
# SQN                                  0.156785
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5560, Train Acc: 0.6747,             Val Acc: 0.5654, Val AUC: 0.5672, lr: 0.001000
# Epoch: 200, Train Loss: 0.2900, Train Acc: 0.8615,             Val Acc: 0.4817, Val AUC: 0.4820, lr: 0.001000
# Epoch: 300, Train Loss: 0.0942, Train Acc: 0.9574,             Val Acc: 0.4764, Val AUC: 0.4770, lr: 0.001000
# Epoch: 400, Train Loss: 0.0511, Train Acc: 0.9871,             Val Acc: 0.4817, Val AUC: 0.4815, lr: 0.001000
# Epoch: 500, Train Loss: 0.0229, Train Acc: 0.9961,             Val Acc: 0.4607, Val AUC: 0.4599, lr: 0.001000
# Epoch: 600, Train Loss: 0.0130, Train Acc: 0.9972,             Val Acc: 0.4660, Val AUC: 0.4650, lr: 0.001000
# Epoch: 700, Train Loss: 0.0123, Train Acc: 0.9989,             Val Acc: 0.5079, Val AUC: 0.5059, lr: 0.001000
# Epoch: 800, Train Loss: 0.0056, Train Acc: 0.9994,             Val Acc: 0.5026, Val AUC: 0.5004, lr: 0.001000
# Epoch: 900, Train Loss: 0.0032, Train Acc: 1.0000,             Val Acc: 0.4974, Val AUC: 0.4951, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0060, Train Acc: 1.0000,             Val Acc: 0.4974, Val AUC: 0.4954, lr: 0.001000
# Test Acc: 0.5378, Test AUC: 0.5454
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10028.530803
# Equity Peak [$]                  10508.650718
# Return [%]                           0.285308
# Buy & Hold Return [%]               33.680525
# Return (Ann.) [%]                    0.146928
# Volatility (Ann.) [%]                 4.17355
# Sharpe Ratio                         0.035205
# Sortino Ratio                        0.049243
# Calmar Ratio                         0.032159
# Max. Drawdown [%]                   -4.568806
# Avg. Drawdown [%]                   -1.520555
# Max. Drawdown Duration      179 days 00:00:00
# Avg. Drawdown Duration       49 days 00:00:00
# # Trades                                   86
# Win Rate [%]                        55.813953
# Best Trade [%]                       9.480391
# Worst Trade [%]                    -21.236939
# Avg. Trade [%]                      -0.023025
# Max. Trade Duration          95 days 00:00:00
# Avg. Trade Duration          12 days 00:00:00
# Profit Factor                        1.067233
# Expectancy [%]                       0.117834
# SQN                                  0.046051
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.4310, Train Acc: 0.7179,             Val Acc: 0.5026, Val AUC: 0.4993, lr: 0.001000
# Epoch: 200, Train Loss: 0.0733, Train Acc: 0.8996,             Val Acc: 0.5236, Val AUC: 0.5179, lr: 0.001000
# Epoch: 300, Train Loss: 0.0496, Train Acc: 0.9540,             Val Acc: 0.5183, Val AUC: 0.5128, lr: 0.001000
# Epoch: 400, Train Loss: 0.0087, Train Acc: 0.9899,             Val Acc: 0.5340, Val AUC: 0.5286, lr: 0.001000
# Epoch: 500, Train Loss: 0.0064, Train Acc: 0.9950,             Val Acc: 0.5393, Val AUC: 0.5336, lr: 0.001000
# Epoch: 600, Train Loss: 0.0050, Train Acc: 0.9983,             Val Acc: 0.5236, Val AUC: 0.5181, lr: 0.001000
# Epoch: 700, Train Loss: 0.0024, Train Acc: 0.9994,             Val Acc: 0.5288, Val AUC: 0.5231, lr: 0.001000
# Epoch: 800, Train Loss: 0.0157, Train Acc: 1.0000,             Val Acc: 0.5131, Val AUC: 0.5083, lr: 0.001000
# Epoch: 900, Train Loss: 0.0024, Train Acc: 1.0000,             Val Acc: 0.5183, Val AUC: 0.5134, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0015, Train Acc: 1.0000,             Val Acc: 0.5393, Val AUC: 0.5341, lr: 0.001000
# Test Acc: 0.5297, Test AUC: 0.5260
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                  10112.34172
# Equity Peak [$]                   10446.36042
# Return [%]                           1.123417
# Buy & Hold Return [%]               33.680539
# Return (Ann.) [%]                    0.577372
# Volatility (Ann.) [%]                3.740529
# Sharpe Ratio                         0.154356
# Sortino Ratio                        0.226352
# Calmar Ratio                         0.159671
# Max. Drawdown [%]                   -3.616015
# Avg. Drawdown [%]                   -0.969448
# Max. Drawdown Duration      245 days 00:00:00
# Avg. Drawdown Duration       37 days 00:00:00
# # Trades                                  110
# Win Rate [%]                        50.909091
# Best Trade [%]                      12.552292
# Worst Trade [%]                    -12.025448
# Avg. Trade [%]                       0.127881
# Max. Trade Duration          46 days 00:00:00
# Avg. Trade Duration           8 days 00:00:00
# Profit Factor                         1.16065
# Expectancy [%]                         0.2027
# SQN                                  0.263911
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.4730, Train Acc: 0.6820,             Val Acc: 0.4869, Val AUC: 0.4878, lr: 0.001000
# Epoch: 200, Train Loss: 0.1652, Train Acc: 0.8536,             Val Acc: 0.5131, Val AUC: 0.5135, lr: 0.001000
# Epoch: 300, Train Loss: 0.0546, Train Acc: 0.9265,             Val Acc: 0.4974, Val AUC: 0.4987, lr: 0.001000
# Epoch: 400, Train Loss: 0.0179, Train Acc: 0.9792,             Val Acc: 0.4921, Val AUC: 0.4926, lr: 0.001000
# Epoch: 500, Train Loss: 0.0202, Train Acc: 0.9910,             Val Acc: 0.4974, Val AUC: 0.4981, lr: 0.001000
# Epoch: 600, Train Loss: 0.0042, Train Acc: 0.9950,             Val Acc: 0.5079, Val AUC: 0.5086, lr: 0.001000
# Epoch: 700, Train Loss: 0.0041, Train Acc: 0.9983,             Val Acc: 0.5131, Val AUC: 0.5134, lr: 0.001000
# Epoch: 800, Train Loss: 0.0020, Train Acc: 0.9989,             Val Acc: 0.5340, Val AUC: 0.5342, lr: 0.001000
# Epoch: 900, Train Loss: 0.0085, Train Acc: 0.9989,             Val Acc: 0.4921, Val AUC: 0.4939, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0022, Train Acc: 1.0000,             Val Acc: 0.5131, Val AUC: 0.5144, lr: 0.001000
# Test Acc: 0.4724, Test AUC: 0.4810
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                  9646.505332
# Equity Peak [$]                  10478.540044
# Return [%]                          -3.534947
# Buy & Hold Return [%]               33.680567
# Return (Ann.) [%]                   -1.837575
# Volatility (Ann.) [%]                4.262408
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                   -7.940369
# Avg. Drawdown [%]                   -1.651902
# Max. Drawdown Duration      223 days 00:00:00
# Avg. Drawdown Duration       50 days 00:00:00
# # Trades                                   87
# Win Rate [%]                        45.977011
# Best Trade [%]                      10.429285
# Worst Trade [%]                    -16.497799
# Avg. Trade [%]                      -0.554061
# Max. Trade Duration          70 days 00:00:00
# Avg. Trade Duration          11 days 00:00:00
# Profit Factor                        0.749096
# Expectancy [%]                      -0.455159
# SQN                                  -0.69922
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
exp.model_framework = 'PyTorch'
exp.model_name = 'LSTMClassifier'
exp.seq_len = 10
exp.period = None
exp.n_epochs = 1000
exp.hidden_size = 64
exp.batch_size = 512
exp.technical_indicators = ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']

# %%
y_pred = exp.run()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5522, Train Acc: 0.6949,             Val Acc: 0.4712, Val AUC: 0.4662, lr: 0.001000
# Epoch: 200, Train Loss: 0.2578, Train Acc: 0.8817,             Val Acc: 0.4974, Val AUC: 0.4912, lr: 0.001000
# Epoch: 300, Train Loss: 0.2043, Train Acc: 0.9293,             Val Acc: 0.5183, Val AUC: 0.5141, lr: 0.001000
# Epoch: 400, Train Loss: 0.3770, Train Acc: 0.9506,             Val Acc: 0.5026, Val AUC: 0.4981, lr: 0.001000
# Epoch: 500, Train Loss: 0.0166, Train Acc: 0.9966,             Val Acc: 0.4974, Val AUC: 0.4917, lr: 0.001000
# Epoch: 600, Train Loss: 0.0341, Train Acc: 0.9989,             Val Acc: 0.5026, Val AUC: 0.4978, lr: 0.001000
# Epoch: 700, Train Loss: 0.0076, Train Acc: 0.9994,             Val Acc: 0.5026, Val AUC: 0.4968, lr: 0.001000
# Epoch: 800, Train Loss: 0.0043, Train Acc: 1.0000,             Val Acc: 0.4869, Val AUC: 0.4812, lr: 0.001000
# Epoch: 900, Train Loss: 0.0058, Train Acc: 1.0000,             Val Acc: 0.4921, Val AUC: 0.4875, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0031, Train Acc: 1.0000,             Val Acc: 0.4869, Val AUC: 0.4820, lr: 0.001000
# Test Acc: 0.5399, Test AUC: 0.5363
# ----------------------------------------
# Start                     2021-07-22 00:00...
# End                       2023-06-30 00:00...
# Duration                    708 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10822.551119
# Equity Peak [$]                  11102.696283
# Return [%]                           8.225511
# Buy & Hold Return [%]               33.680553
# Return (Ann.) [%]                    4.157693
# Volatility (Ann.) [%]                  3.7316
# Sharpe Ratio                         1.114185
# Sortino Ratio                        1.798818
# Calmar Ratio                          1.36932
# Max. Drawdown [%]                   -3.036319
# Avg. Drawdown [%]                   -0.509027
# Max. Drawdown Duration      211 days 00:00:00
# Avg. Drawdown Duration       25 days 00:00:00
# # Trades                                   92
# Win Rate [%]                        66.304348
# Best Trade [%]                        9.41464
# Worst Trade [%]                     -7.363486
# Avg. Trade [%]                       0.758169
# Max. Trade Duration          47 days 00:00:00
# Avg. Trade Duration          10 days 00:00:00
# Profit Factor                        1.804781
# Expectancy [%]                       0.823466
# SQN                                  2.129766
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %% [markdown]
# ### Sub Experiments 3 - With Technical Indicator + seq_len = 20

# %%
exp.model_framework = 'PyTorch'
exp.model_name = 'LSTMClassifier'
exp.seq_len = 20
exp.period = None
exp.n_epochs = 1000
exp.hidden_size = 64
exp.batch_size = 512
exp.technical_indicators = ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']

# %%
y_pred = exp.run()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 20
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 64
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 64, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.5970, Train Acc: 0.6706,             Val Acc: 0.4751, Val AUC: 0.4804, lr: 0.001000
# Epoch: 200, Train Loss: 0.3307, Train Acc: 0.8404,             Val Acc: 0.4807, Val AUC: 0.4873, lr: 0.001000
# Epoch: 300, Train Loss: 0.2134, Train Acc: 0.9210,             Val Acc: 0.4862, Val AUC: 0.4905, lr: 0.001000
# Epoch: 400, Train Loss: 0.1724, Train Acc: 0.9594,             Val Acc: 0.4696, Val AUC: 0.4759, lr: 0.001000
# Epoch: 500, Train Loss: 0.0697, Train Acc: 0.9865,             Val Acc: 0.4917, Val AUC: 0.4965, lr: 0.001000
# Epoch: 600, Train Loss: 0.0447, Train Acc: 0.9966,             Val Acc: 0.4807, Val AUC: 0.4839, lr: 0.001000
# Epoch: 700, Train Loss: 0.0926, Train Acc: 0.9774,             Val Acc: 0.4917, Val AUC: 0.4947, lr: 0.001000
# Epoch: 800, Train Loss: 0.0217, Train Acc: 0.9994,             Val Acc: 0.4807, Val AUC: 0.4836, lr: 0.001000
# Epoch: 900, Train Loss: 0.0125, Train Acc: 1.0000,             Val Acc: 0.4917, Val AUC: 0.4950, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0708, Train Acc: 0.9842,             Val Acc: 0.4917, Val AUC: 0.4965, lr: 0.001000
# Test Acc: 0.4885, Test AUC: 0.5026
# ----------------------------------------
# Start                     2021-08-05 00:00...
# End                       2023-06-30 00:00...
# Duration                    694 days 00:00:00
# Exposure Time [%]                   99.582463
# Equity Final [$]                  9459.614966
# Equity Peak [$]                  10140.302543
# Return [%]                           -5.40385
# Buy & Hold Return [%]               33.444194
# Return (Ann.) [%]                   -2.880347
# Volatility (Ann.) [%]                2.891813
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                   -6.712695
# Avg. Drawdown [%]                   -1.444704
# Max. Drawdown Duration      450 days 00:00:00
# Avg. Drawdown Duration       77 days 00:00:00
# # Trades                                   21
# Win Rate [%]                        61.904762
# Best Trade [%]                      11.662656
# Worst Trade [%]                      -25.1006
# Avg. Trade [%]                      -1.650871
# Max. Trade Duration         225 days 00:00:00
# Avg. Trade Duration          39 days 00:00:00
# Profit Factor                        0.614556
# Expectancy [%]                      -1.267834
# SQN                                 -0.971393
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
exp.model_framework = 'PyTorch'
exp.model_name = 'LSTMClassifier'
exp.seq_len = 20
exp.period = None
exp.n_epochs = 1000
exp.hidden_size = 128
exp.batch_size = 512
exp.technical_indicators = ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']

# %%
y_pred = exp.run()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: None
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 20
# Train Ratio: 0.7
# Test Ratio: 0.2
# C: 10.0
# Batch Size: 512
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.001
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# LSTMClassifier(
#   (lstm): LSTM(16, 128, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=128, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# ----------------------------------------
# Epoch: 100, Train Loss: 0.4232, Train Acc: 0.7783,             Val Acc: 0.5138, Val AUC: 0.5052, lr: 0.001000
# Epoch: 200, Train Loss: 0.1598, Train Acc: 0.9385,             Val Acc: 0.5249, Val AUC: 0.5187, lr: 0.001000
# Epoch: 300, Train Loss: 0.0291, Train Acc: 0.9927,             Val Acc: 0.5028, Val AUC: 0.4978, lr: 0.001000
# Epoch: 400, Train Loss: 0.1283, Train Acc: 0.9786,             Val Acc: 0.5249, Val AUC: 0.5214, lr: 0.001000
# Epoch: 500, Train Loss: 0.0412, Train Acc: 0.9972,             Val Acc: 0.5083, Val AUC: 0.5023, lr: 0.001000
# Epoch: 600, Train Loss: 0.0026, Train Acc: 1.0000,             Val Acc: 0.4972, Val AUC: 0.4921, lr: 0.001000
# Epoch: 700, Train Loss: 0.0012, Train Acc: 1.0000,             Val Acc: 0.5083, Val AUC: 0.5035, lr: 0.001000
# Epoch: 800, Train Loss: 0.0156, Train Acc: 1.0000,             Val Acc: 0.5028, Val AUC: 0.4984, lr: 0.001000
# Epoch: 900, Train Loss: 0.0020, Train Acc: 1.0000,             Val Acc: 0.4972, Val AUC: 0.4924, lr: 0.001000
# Epoch: 1000, Train Loss: 0.0008, Train Acc: 1.0000,             Val Acc: 0.4917, Val AUC: 0.4861, lr: 0.001000
# Test Acc: 0.5157, Test AUC: 0.5147
# ----------------------------------------
# Start                     2021-08-05 00:00...
# End                       2023-06-30 00:00...
# Duration                    694 days 00:00:00
# Exposure Time [%]                   99.582463
# Equity Final [$]                 10091.366036
# Equity Peak [$]                  10535.981611
# Return [%]                            0.91366
# Buy & Hold Return [%]               33.444236
# Return (Ann.) [%]                    0.479637
# Volatility (Ann.) [%]                3.769894
# Sharpe Ratio                         0.127228
# Sortino Ratio                        0.177159
# Calmar Ratio                         0.113659
# Max. Drawdown [%]                   -4.219973
# Avg. Drawdown [%]                    -0.46359
# Max. Drawdown Duration      498 days 00:00:00
# Avg. Drawdown Duration       34 days 00:00:00
# # Trades                                   96
# Win Rate [%]                            56.25
# Best Trade [%]                       9.259695
# Worst Trade [%]                    -12.909892
# Avg. Trade [%]                      -0.055409
# Max. Trade Duration          47 days 00:00:00
# Avg. Trade Duration          10 days 00:00:00
# Profit Factor                        1.016642
# Expectancy [%]                       0.024529
# SQN                                  0.228024
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object
