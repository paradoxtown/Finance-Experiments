# %% [markdown]
# # Experiments

# %% [markdown]
# ## Preparation

# %%
# !pip3 install backtesting
# Out:
# Collecting backtesting
#   Downloading Backtesting-0.3.3.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from backtesting) (1.22.4)
# Requirement already satisfied: pandas!=0.25.0,>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from backtesting) (1.5.3)
# Requirement already satisfied: bokeh>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from backtesting) (3.1.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (1.1.0)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (23.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (6.3.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (2023.7.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=0.25.0,>=0.25.0->backtesting) (2022.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh>=1.4.0->backtesting) (2.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas!=0.25.0,>=0.25.0->backtesting) (1.16.0)
# Building wheels for collected packages: backtesting
#   Building wheel for backtesting (setup.py) ... done
#   Created wheel for backtesting: filename=Backtesting-0.3.3-py3-none-any.whl size=173802 sha256=ada57a6120fcde2c5451afca70b842275a0491aa44730211c6b913e16dbe98bc
#   Stored in directory: /root/.cache/pip/wheels/e2/30/7f/19cbe31987c6ebdb47f1f510343249066711609e3da2d57176
# Successfully built backtesting
# Installing collected packages: backtesting
# Successfully installed backtesting-0.3.3

# %%
# https://stackoverflow.com/questions/61362725/how-to-install-talib-module-on-google-colab-instance-using-pip
# !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/libta-lib0_0.4.0-oneiric1_amd64.deb -qO libta.deb
# !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/ta-lib0-dev_0.4.0-oneiric1_amd64.deb -qO ta.deb
# !dpkg -i libta.deb ta.deb
# !pip install ta-lib
# Out:
# Selecting previously unselected package libta-lib0.
# (Reading database ... 120500 files and directories currently installed.)
# Preparing to unpack libta.deb ...
# Unpacking libta-lib0 (0.4.0-oneiric1) ...
# Selecting previously unselected package ta-lib0-dev.
# Preparing to unpack ta.deb ...
# Unpacking ta-lib0-dev (0.4.0-oneiric1) ...
# Setting up libta-lib0 (0.4.0-oneiric1) ...
# Setting up ta-lib0-dev (0.4.0-oneiric1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# Collecting ta-lib
#   Downloading TA-Lib-0.4.27.tar.gz (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.4/266.4 kB 6.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ta-lib) (1.22.4)
# Building wheels for collected packages: ta-lib
#   Building wheel for ta-lib (pyproject.toml) ... done
#   Created wheel for ta-lib: filename=TA_Lib-0.4.27-cp310-cp310-linux_x86_64.whl size=1570183 sha256=1c2d3e0d1e993e56181bfeae90d197a6a59d96834f84a708d2252c3a165daea3
#   Stored in directory: /root/.cache/pip/wheels/cc/d2/af/ede611220f2719d334f1232aa623df38fe124a4235c9447f71
# Successfully built ta-lib
# Installing collected packages: ta-lib
# Successfully installed ta-lib-0.4.27

# %%
import os

path = "/content/drive/My Drive/Finance-Experiments"

os.chdir(path)
os.listdir(path)
# Out:
# ['datasets',
#  'MyStrategy.html',
#  '.git',
#  'models',
#  'simulator.py',
#  '__pycache__',
#  'ckpt',
#  'index.html',
#  'test.ipynb',
#  'experiments.ipynb',
#  '.ipynb_checkpoints',
#  'test.py',
#  'ta.deb',
#  'libta.deb',
#  'requirements.txt',
#  '.gitignore',
#  'exp_classification.py',
#  'data_processor.py',
#  'colab_exp.ipynb']

# %%
import exp_classification as exp
# Out:
# /usr/local/lib/python3.10/dist-packages/backtesting/_plotting.py:50: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support (e.g. PyCharm, Spyder IDE). Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '

# %% [markdown]
# ## Experiment 1: Logistics Regression

# %% [markdown]
# ### Sub Experiment 1 - No Technical Indicators

# %%
exp.model_framework = 'Sklearn'
exp.model_name = 'LogisticRegression'
exp.seq_len = 1
exp.period = '5y'
exp.scale = True
exp.C = 10
exp.technical_indicators = []

# %%
y_pred = exp.run()
# Out:
# Tiker: AAPL
# Period: 5y
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: []
# Target: Trend
# Sequence Length: 1
# Train Ratio: 0.7
# Test Ratio: 0.2
# Batch Size: 32
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 1e-05
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LogisticRegression
# Model Framework: Sklearn
# ----------------------------------------
# Training LogisticRegression model...
# (905, 5) (905,)
# Train Acc: 0.5525, Val Acc: 0.4851
# Test Acc: 0.4921, Test AUC: 0.4909
# ----------------------------------------
# Start                     2022-08-04 00:00...
# End                       2023-08-04 00:00...
# Duration                    365 days 00:00:00
# Exposure Time [%]                   99.206349
# Equity Final [$]                  10404.48031
# Equity Peak [$]                  10439.346424
# Return [%]                           4.044803
# Buy & Hold Return [%]               10.413549
# Return (Ann.) [%]                    4.044803
# Volatility (Ann.) [%]                3.339728
# Sharpe Ratio                         1.211118
# Sortino Ratio                        2.004061
# Calmar Ratio                          1.90275
# Max. Drawdown [%]                   -2.125767
# Avg. Drawdown [%]                   -0.435547
# Max. Drawdown Duration       60 days 00:00:00
# Avg. Drawdown Duration       15 days 00:00:00
# # Trades                                  103
# Win Rate [%]                        58.252427
# Best Trade [%]                        8.86418
# Worst Trade [%]                    -11.883618
# Avg. Trade [%]                        0.32993
# Max. Trade Duration          35 days 00:00:00
# Avg. Trade Duration           5 days 00:00:00
# Profit Factor                        1.468442
# Expectancy [%]                       0.367539
# SQN                                  1.868977
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %% [markdown]
# ### Sub Experiment 2 - With Technical Indicators

# %%
exp.model_framework = 'Sklearn'
exp.model_name = 'LogisticRegression'
exp.technical_indicators = ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'RSI', 'RSIROCP']
exp.period = '5y'
exp.seq_len = 1
exp.scale = True
exp.C = 10

# %%
y_pred = exp.run()
# Out:
# Tiker: AAPL
# Period: 5y
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 1
# Train Ratio: 0.7
# Test Ratio: 0.2
# Batch Size: 32
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 1e-05
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LogisticRegression
# Model Framework: Sklearn
# ----------------------------------------
# Training LogisticRegression model...
# (885, 13) (885,)
# Train Acc: 0.5548, Val Acc: 0.4747
# Test Acc: 0.4919, Test AUC: 0.4933
# ----------------------------------------
# Start                     2022-08-12 00:00...
# End                       2023-08-04 00:00...
# Duration                    357 days 00:00:00
# Exposure Time [%]                   99.186992
# Equity Final [$]                 10128.963422
# Equity Peak [$]                  10264.016079
# Return [%]                           1.289634
# Buy & Hold Return [%]                6.230541
# Return (Ann.) [%]                    1.321296
# Volatility (Ann.) [%]                3.962073
# Sharpe Ratio                         0.333486
# Sortino Ratio                        0.492002
# Calmar Ratio                         0.378768
# Max. Drawdown [%]                   -3.488405
# Avg. Drawdown [%]                   -1.172023
# Max. Drawdown Duration      211 days 00:00:00
# Avg. Drawdown Duration       50 days 00:00:00
# # Trades                                   59
# Win Rate [%]                        59.322034
# Best Trade [%]                       6.858793
# Worst Trade [%]                    -14.253528
# Avg. Trade [%]                       0.071433
# Max. Trade Duration          28 days 00:00:00
# Avg. Trade Duration           8 days 00:00:00
# Profit Factor                        1.124277
# Expectancy [%]                       0.149123
# SQN                                   0.48443
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %% [markdown]
# ### Sub Experiment 3 - With Technical Indicators
# - lr = 1e-5
# - max_iter = 10000

# %%
exp.model_framework = 'Sklearn'
exp.model_name = 'LogisticRegression'
exp.technical_indicators = ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'RSI', 'RSIROCP']
exp.seq_len = 1
exp.scale = True
exp.C = 10
exp.max_iter = 10000
exp.lr = 1e-5

# %%
y_pred = exp.run()
# Out:
# Tiker: AAPL
# Period: 5y
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 1
# Train Ratio: 0.7
# Test Ratio: 0.2
# Batch Size: 32
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 1e-05
# Number of Epochs: 1000
# Max Iterations: 10000
# Model Name: LogisticRegression
# Model Framework: Sklearn
# ----------------------------------------
# Training LogisticRegression model...
# (885, 13) (885,)
# Train Acc: 0.5537, Val Acc: 0.4747
# Test Acc: 0.4919, Test AUC: 0.4933
# ----------------------------------------
# Start                     2022-08-12 00:00...
# End                       2023-08-04 00:00...
# Duration                    357 days 00:00:00
# Exposure Time [%]                   99.186992
# Equity Final [$]                 10128.963218
# Equity Peak [$]                  10264.015987
# Return [%]                           1.289632
# Buy & Hold Return [%]                6.230541
# Return (Ann.) [%]                    1.321294
# Volatility (Ann.) [%]                3.962073
# Sharpe Ratio                         0.333485
# Sortino Ratio                        0.492001
# Calmar Ratio                         0.378767
# Max. Drawdown [%]                   -3.488406
# Avg. Drawdown [%]                   -1.172023
# Max. Drawdown Duration      211 days 00:00:00
# Avg. Drawdown Duration       50 days 00:00:00
# # Trades                                   59
# Win Rate [%]                        59.322034
# Best Trade [%]                       6.858782
# Worst Trade [%]                    -14.253535
# Avg. Trade [%]                       0.071433
# Max. Trade Duration          28 days 00:00:00
# Avg. Trade Duration           8 days 00:00:00
# Profit Factor                        1.124277
# Expectancy [%]                       0.149123
# SQN                                  0.484429
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %% [markdown]
# ## Experiment2: LSTM

# %% [markdown]
# ### Sub Experiment 1 - No Technical Indicators

# %%
import exp_classification as exp
exp.model_framework = 'PyTorch'
exp.model_name = 'LSTMClassifier'
exp.seq_len = 10
exp.scale = True
exp.n_epochs = 2000
exp.technical_indicators = []
exp.input_size = 5

# %%
y_pred = exp.run()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: 10y
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: []
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# Batch Size: 32
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 1e-05
# Number of Epochs: 2000
# Max Iterations: 10000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# Epoch: 100, Train Loss: 0.6585, Train Acc: 0.5352,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 200, Train Loss: 0.6584, Train Acc: 0.5352,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 300, Train Loss: 0.6594, Train Acc: 0.5374,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 400, Train Loss: 0.6608, Train Acc: 0.5385,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 500, Train Loss: 0.6626, Train Acc: 0.5363,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 600, Train Loss: 0.6642, Train Acc: 0.5352,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 700, Train Loss: 0.6620, Train Acc: 0.5402,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 800, Train Loss: 0.6636, Train Acc: 0.5391,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 900, Train Loss: 0.6611, Train Acc: 0.5380,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1000, Train Loss: 0.6617, Train Acc: 0.5374,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1100, Train Loss: 0.6596, Train Acc: 0.5397,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1200, Train Loss: 0.6599, Train Acc: 0.5424,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1300, Train Loss: 0.6592, Train Acc: 0.5441,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1400, Train Loss: 0.6624, Train Acc: 0.5513,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1500, Train Loss: 0.6601, Train Acc: 0.5502,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1600, Train Loss: 0.6602, Train Acc: 0.5507,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1700, Train Loss: 0.6579, Train Acc: 0.5496,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1800, Train Loss: 0.6621, Train Acc: 0.5519,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 1900, Train Loss: 0.6564, Train Acc: 0.5507,                   Val Acc: 0.5130, Val AUC: 0.5000
# Epoch: 2000, Train Loss: 0.6560, Train Acc: 0.5535,                   Val Acc: 0.5130, Val AUC: 0.5000
# Test Acc: 0.5091, Test AUC: 0.4962
# ----------------------------------------
# Start                     2021-08-17 00:00...
# End                       2023-08-04 00:00...
# Duration                    717 days 00:00:00
# Exposure Time [%]                    99.59596
# Equity Final [$]                 10403.870084
# Equity Peak [$]                  10442.577448
# Return [%]                           4.038701
# Buy & Hold Return [%]               22.409772
# Return (Ann.) [%]                    2.036083
# Volatility (Ann.) [%]                2.410687
# Sharpe Ratio                         0.844607
# Sortino Ratio                        1.311335
# Calmar Ratio                         0.914729
# Max. Drawdown [%]                   -2.225886
# Avg. Drawdown [%]                   -0.847615
# Max. Drawdown Duration      602 days 00:00:00
# Avg. Drawdown Duration      100 days 00:00:00
# # Trades                                    4
# Win Rate [%]                             75.0
# Best Trade [%]                      22.039906
# Worst Trade [%]                     -1.547042
# Avg. Trade [%]                      10.948659
# Max. Trade Duration         582 days 00:00:00
# Avg. Trade Duration         211 days 00:00:00
# Profit Factor                       30.568613
# Expectancy [%]                      11.435972
# SQN                                  1.543213
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                      Size  EntryBa...
# dtype: object

# %%
list(y_pred).count(0), list(y_pred).count(1), len(y_pred)
# Out:
# (355, 140, 495)

# %%
sim_data = exp.data_processor.get_simulate_data()
sim_data['y_pred'] = y_pred

# %%
bt = sim.backtest(sim_data)
bt.run()
# Out:
# Start                     2021-08-03 00:00...
# End                       2023-07-21 00:00...
# Duration                    717 days 00:00:00
# Exposure Time [%]                    99.59596
# Equity Final [$]                  9574.128723
# Equity Peak [$]                  10154.899861
# Return [%]                          -4.258713
# Buy & Hold Return [%]                31.77879
# Return (Ann.) [%]                   -2.191228
# Volatility (Ann.) [%]                4.004645
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                   -5.827444
# Avg. Drawdown [%]                   -1.437004
# Max. Drawdown Duration      382 days 00:00:00
# Avg. Drawdown Duration       79 days 00:00:00
# # Trades                                   83
# Win Rate [%]                         50.60241
# Best Trade [%]                      16.892116
# Worst Trade [%]                    -24.780878
# Avg. Trade [%]                      -0.387745
# Max. Trade Duration         126 days 00:00:00
# Avg. Trade Duration          10 days 00:00:00
# Profit Factor                        0.847126
# Expectancy [%]                      -0.264445
# SQN                                 -0.724881
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %% [markdown]
# ### Sub Experiment 2 - With Technical Indicators

# %%
exp.model_framework = 'PyTorch'
exp.model_name = 'LSTMClassifier'
exp.seq_len = 10
exp.n_epochs = 2000
exp.scale = True
exp.technical_indicators = ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']

# %%
y_pred = exp.run()
# Out:
# Tiker: AAPL
# Period: 10y
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# Batch Size: 32
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.0001
# Number of Epochs: 2000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# Epoch: 100, Train Loss: 0.6245, Train Acc: 0.5934,                   Val Acc: 0.5183, Val AUC: 0.5000
# Epoch: 200, Train Loss: 0.5576, Train Acc: 0.6854,                   Val Acc: 0.5183, Val AUC: 0.5000
# Epoch: 300, Train Loss: 0.4248, Train Acc: 0.7785,                   Val Acc: 0.5183, Val AUC: 0.5000
# Epoch: 400, Train Loss: 0.2964, Train Acc: 0.8721,                   Val Acc: 0.5236, Val AUC: 0.5062
# Epoch: 500, Train Loss: 0.1796, Train Acc: 0.9237,                   Val Acc: 0.5288, Val AUC: 0.5116
# Epoch: 600, Train Loss: 0.0922, Train Acc: 0.9602,                   Val Acc: 0.5288, Val AUC: 0.5120
# Epoch: 700, Train Loss: 0.0483, Train Acc: 0.9933,                   Val Acc: 0.5445, Val AUC: 0.5287
# Epoch: 800, Train Loss: 0.0409, Train Acc: 0.9910,                   Val Acc: 0.5340, Val AUC: 0.5186
# Epoch: 900, Train Loss: 0.0107, Train Acc: 0.9983,                   Val Acc: 0.5602, Val AUC: 0.5458
# Epoch: 1000, Train Loss: 0.0071, Train Acc: 0.9899,                   Val Acc: 0.5812, Val AUC: 0.5694
# Epoch: 1100, Train Loss: 0.0042, Train Acc: 1.0000,                   Val Acc: 0.5393, Val AUC: 0.5256
# Epoch: 1200, Train Loss: 0.0038, Train Acc: 1.0000,                   Val Acc: 0.5445, Val AUC: 0.5306
# Epoch: 1300, Train Loss: 0.0021, Train Acc: 1.0000,                   Val Acc: 0.5445, Val AUC: 0.5310
# Epoch: 1400, Train Loss: 0.0015, Train Acc: 1.0000,                   Val Acc: 0.5393, Val AUC: 0.5260
# Epoch: 1500, Train Loss: 0.0012, Train Acc: 1.0000,                   Val Acc: 0.5497, Val AUC: 0.5372
# Epoch: 1600, Train Loss: 0.0026, Train Acc: 1.0000,                   Val Acc: 0.5445, Val AUC: 0.5318
# Epoch: 1700, Train Loss: 0.0021, Train Acc: 1.0000,                   Val Acc: 0.5393, Val AUC: 0.5264
# Epoch: 1800, Train Loss: 0.0009, Train Acc: 1.0000,                   Val Acc: 0.5550, Val AUC: 0.5427
# Epoch: 1900, Train Loss: 0.0016, Train Acc: 1.0000,                   Val Acc: 0.5445, Val AUC: 0.5306
# Epoch: 2000, Train Loss: 0.0006, Train Acc: 1.0000,                   Val Acc: 0.5288, Val AUC: 0.5147
# Test Acc: 0.5031, Test AUC: 0.4917

# %%
list(y_pred).count(0), list(y_pred).count(1), len(y_pred)
# Out:
# (182, 297, 479)

# %%
sim_data = exp.data_processor.get_simulate_data()
sim_data['y_pred'] = y_pred

# %%
bt = sim.backtest(sim_data)
bt.run()
# Out:
# Start                     2021-08-25 00:00...
# End                       2023-07-21 00:00...
# Duration                    695 days 00:00:00
# Exposure Time [%]                   99.582463
# Equity Final [$]                 10331.838782
# Equity Peak [$]                  10397.283194
# Return [%]                           3.318388
# Buy & Hold Return [%]               30.694761
# Return (Ann.) [%]                    1.732283
# Volatility (Ann.) [%]                4.149945
# Sharpe Ratio                         0.417423
# Sortino Ratio                        0.665823
# Calmar Ratio                         0.307218
# Max. Drawdown [%]                   -5.638615
# Avg. Drawdown [%]                   -0.911213
# Max. Drawdown Duration      555 days 00:00:00
# Avg. Drawdown Duration       75 days 00:00:00
# # Trades                                  125
# Win Rate [%]                             57.6
# Best Trade [%]                      10.399407
# Worst Trade [%]                    -11.033909
# Avg. Trade [%]                        0.27897
# Max. Trade Duration          33 days 00:00:00
# Avg. Trade Duration           8 days 00:00:00
# Profit Factor                        1.309613
# Expectancy [%]                       0.335102
# SQN                                  0.866149
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %% [markdown]
# ### Sub Experiments 3 - With Technical Indicator + seq_len = 20

# %%
exp.model_framework = 'PyTorch'
exp.model_name = 'LSTMClassifier'
exp.seq_len = 20
exp.scale = True
exp.technical_indicators = ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']

# %%
y_pred = exp.run()
# Out:
# Tiker: AAPL
# Period: 10y
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'SMA', 'EMA', 'WMA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 20
# Train Ratio: 0.7
# Test Ratio: 0.2
# Batch Size: 32
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.0001
# Number of Epochs: 2000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# Epoch: 100, Train Loss: 0.5459, Train Acc: 0.6300,                   Val Acc: 0.5138, Val AUC: 0.5000
# Epoch: 200, Train Loss: 0.4511, Train Acc: 0.7242,                   Val Acc: 0.5249, Val AUC: 0.5117
# Epoch: 300, Train Loss: 0.3281, Train Acc: 0.8071,                   Val Acc: 0.5193, Val AUC: 0.5081
# Epoch: 400, Train Loss: 0.2686, Train Acc: 0.8438,                   Val Acc: 0.5083, Val AUC: 0.4971
# Epoch: 500, Train Loss: 0.1198, Train Acc: 0.8878,                   Val Acc: 0.5470, Val AUC: 0.5359
# Epoch: 600, Train Loss: 0.0855, Train Acc: 0.9227,                   Val Acc: 0.5856, Val AUC: 0.5775
# Epoch: 700, Train Loss: 0.0351, Train Acc: 0.9774,                   Val Acc: 0.5635, Val AUC: 0.5557
# Epoch: 800, Train Loss: 0.0266, Train Acc: 0.9622,                   Val Acc: 0.5691, Val AUC: 0.5629
# Epoch: 900, Train Loss: 0.0103, Train Acc: 0.9752,                   Val Acc: 0.5470, Val AUC: 0.5393
# Epoch: 1000, Train Loss: 0.0067, Train Acc: 0.9944,                   Val Acc: 0.5525, Val AUC: 0.5444
# Epoch: 1100, Train Loss: 0.0295, Train Acc: 0.9966,                   Val Acc: 0.5746, Val AUC: 0.5668
# Epoch: 1200, Train Loss: 0.0047, Train Acc: 0.9938,                   Val Acc: 0.5525, Val AUC: 0.5456
# Epoch: 1300, Train Loss: 0.0019, Train Acc: 0.9994,                   Val Acc: 0.5856, Val AUC: 0.5781
# Epoch: 1400, Train Loss: 0.0038, Train Acc: 0.9757,                   Val Acc: 0.5746, Val AUC: 0.5686
# Epoch: 1500, Train Loss: 0.0024, Train Acc: 1.0000,                   Val Acc: 0.5414, Val AUC: 0.5333
# Epoch: 1600, Train Loss: 0.0168, Train Acc: 1.0000,                   Val Acc: 0.5635, Val AUC: 0.5576
# Epoch: 1700, Train Loss: 0.0032, Train Acc: 1.0000,                   Val Acc: 0.5580, Val AUC: 0.5491
# Epoch: 1800, Train Loss: 0.0020, Train Acc: 0.9797,                   Val Acc: 0.5580, Val AUC: 0.5491
# Epoch: 1900, Train Loss: 0.0011, Train Acc: 1.0000,                   Val Acc: 0.5359, Val AUC: 0.5282
# Epoch: 2000, Train Loss: 0.0010, Train Acc: 1.0000,                   Val Acc: 0.5359, Val AUC: 0.5291
# Test Acc: 0.5136, Test AUC: 0.5103

# %%
sim_data = exp.data_processor.get_simulate_data()
sim_data['y_pred'] = y_pred

# %%
bt = sim.backtest(sim_data)
bt.run()
# Out:
# Start                     2021-08-25 00:00...
# End                       2023-07-21 00:00...
# Duration                    695 days 00:00:00
# Exposure Time [%]                   99.582463
# Equity Final [$]                 10331.838782
# Equity Peak [$]                  10397.283194
# Return [%]                           3.318388
# Buy & Hold Return [%]               30.694761
# Return (Ann.) [%]                    1.732283
# Volatility (Ann.) [%]                4.149945
# Sharpe Ratio                         0.417423
# Sortino Ratio                        0.665823
# Calmar Ratio                         0.307218
# Max. Drawdown [%]                   -5.638615
# Avg. Drawdown [%]                   -0.911213
# Max. Drawdown Duration      555 days 00:00:00
# Avg. Drawdown Duration       75 days 00:00:00
# # Trades                                  125
# Win Rate [%]                             57.6
# Best Trade [%]                      10.399407
# Worst Trade [%]                    -11.033909
# Avg. Trade [%]                        0.27897
# Max. Trade Duration          33 days 00:00:00
# Avg. Trade Duration           8 days 00:00:00
# Profit Factor                        1.309613
# Expectancy [%]                       0.335102
# SQN                                  0.866149
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %% [markdown]
# ### Sub Experiments 4 - With Technical Indicators
# technical_indicators = ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'RSI', 'RSIROCP']

# %%
exp.model_framework = 'PyTorch'
exp.model_name = 'LSTMClassifier'
exp.seq_len = 10
exp.scale = True
exp.n_epochs = 2000
exp.technical_indicators =  ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'RSI', 'RSIROCP']

# %%
y_pred = exp.run()
# Out:
# Tiker: AAPL
# Period: 10y
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: ['CROCP', 'OROCP', 'LROCP', 'HROCP', 'VROCP', 'MA', 'RSI', 'RSIROCP']
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# Batch Size: 32
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 0.0001
# Number of Epochs: 2000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# Epoch: 100, Train Loss: 0.6164, Train Acc: 0.5945,                   Val Acc: 0.5183, Val AUC: 0.5000
# Epoch: 200, Train Loss: 0.5272, Train Acc: 0.6792,                   Val Acc: 0.5288, Val AUC: 0.5109
# Epoch: 300, Train Loss: 0.4499, Train Acc: 0.7572,                   Val Acc: 0.5183, Val AUC: 0.5000
# Epoch: 400, Train Loss: 0.2179, Train Acc: 0.8615,                   Val Acc: 0.5236, Val AUC: 0.5066
# Epoch: 500, Train Loss: 0.1181, Train Acc: 0.9159,                   Val Acc: 0.5288, Val AUC: 0.5124
# Epoch: 600, Train Loss: 0.0411, Train Acc: 0.9445,                   Val Acc: 0.5288, Val AUC: 0.5124
# Epoch: 700, Train Loss: 0.0163, Train Acc: 0.9675,                   Val Acc: 0.5288, Val AUC: 0.5132
# Epoch: 800, Train Loss: 0.0080, Train Acc: 0.9905,                   Val Acc: 0.5340, Val AUC: 0.5182
# Epoch: 900, Train Loss: 0.0047, Train Acc: 0.9955,                   Val Acc: 0.5183, Val AUC: 0.5027
# Epoch: 1000, Train Loss: 0.0035, Train Acc: 0.9893,                   Val Acc: 0.5340, Val AUC: 0.5198
# Epoch: 1100, Train Loss: 0.0016, Train Acc: 0.9983,                   Val Acc: 0.5393, Val AUC: 0.5252
# Epoch: 1200, Train Loss: 0.0028, Train Acc: 0.9910,                   Val Acc: 0.5079, Val AUC: 0.4930
# Epoch: 1300, Train Loss: 0.0009, Train Acc: 0.9994,                   Val Acc: 0.5236, Val AUC: 0.5097
# Epoch: 1400, Train Loss: 0.0005, Train Acc: 1.0000,                   Val Acc: 0.5183, Val AUC: 0.5038
# Epoch: 1500, Train Loss: 0.0006, Train Acc: 1.0000,                   Val Acc: 0.5183, Val AUC: 0.5038
# Epoch: 1600, Train Loss: 0.0006, Train Acc: 1.0000,                   Val Acc: 0.5079, Val AUC: 0.4926
# Epoch: 1700, Train Loss: 0.0016, Train Acc: 0.9938,                   Val Acc: 0.5288, Val AUC: 0.5143
# Epoch: 1800, Train Loss: 0.0009, Train Acc: 1.0000,                   Val Acc: 0.5183, Val AUC: 0.5027
# Epoch: 1900, Train Loss: 0.0003, Train Acc: 1.0000,                   Val Acc: 0.5079, Val AUC: 0.4930
# Epoch: 2000, Train Loss: 0.0002, Train Acc: 1.0000,                   Val Acc: 0.5131, Val AUC: 0.4988
# Test Acc: 0.5215, Test AUC: 0.5161

# %%
sim_data = exp.data_processor.get_simulate_data()
sim_data['y_pred'] = y_pred

# %%
bt = sim.backtest(sim_data)
bt.run()
# Out:
# Start                     2021-08-11 00:00...
# End                       2023-07-21 00:00...
# Duration                    709 days 00:00:00
# Exposure Time [%]                   99.591002
# Equity Final [$]                 10193.733202
# Equity Peak [$]                  10347.795183
# Return [%]                           1.937332
# Buy & Hold Return [%]               32.934849
# Return (Ann.) [%]                    0.993737
# Volatility (Ann.) [%]                 4.02988
# Sharpe Ratio                         0.246592
# Sortino Ratio                        0.359429
# Calmar Ratio                         0.227254
# Max. Drawdown [%]                   -4.372802
# Avg. Drawdown [%]                   -0.905806
# Max. Drawdown Duration      505 days 00:00:00
# Avg. Drawdown Duration       63 days 00:00:00
# # Trades                                  107
# Win Rate [%]                        61.682243
# Best Trade [%]                      13.681373
# Worst Trade [%]                    -12.436665
# Avg. Trade [%]                       0.672828
# Max. Trade Duration          69 days 00:00:00
# Avg. Trade Duration           9 days 00:00:00
# Profit Factor                        1.679867
# Expectancy [%]                       0.754892
# SQN                                  0.391656
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %% [markdown]
# ### Sub Experiment 5 - No Technical Indicators
# - lr = 1e5

# %%
exp.model_framework = 'PyTorch'
exp.model_name = 'LSTMClassifier'
exp.seq_len = 10
exp.scale = True
exp.n_epochs = 1000
exp.technical_indicators = []
exp.input_size = 5

# %%
y_pred = exp.run()
# Out:
# /content/drive/My Drive/finance_experiments/data_processor.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.hist['Target'] = self.hist['Close'].diff()
# /content/drive/My Drive/finance_experiments/data_processor.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.hist['Target'] = self.hist['Target'].apply(lambda x: 1 if x > 0 else 0)
# /content/drive/My Drive/finance_experiments/data_processor.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.hist['Target'] = self.hist['Target'].shift(-1, fill_value=1)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:71: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# Tiker: AAPL
# Period: 10y
# Interval: 1d
# Features: ['Open', 'Close', 'High', 'Low', 'Volume']
# Technical Indicators: []
# Target: Trend
# Sequence Length: 10
# Train Ratio: 0.7
# Test Ratio: 0.2
# Batch Size: 32
# Input Size: 5
# Hidden Size: 128
# Number of Layers: 1
# Number of Classes: 1
# Learning Rate: 1e-05
# Number of Epochs: 1000
# Max Iterations: 1000
# Model Name: LSTMClassifier
# Model Framework: PyTorch
# ----------------------------------------
# Training LSTMClassifier model...
# Epoch: 100, Train Loss: 0.6923, Train Acc: 0.5347,                   Val Acc: 0.5026, Val AUC: 0.5000
# Epoch: 200, Train Loss: 0.6888, Train Acc: 0.5347,                   Val Acc: 0.5026, Val AUC: 0.5000
# Epoch: 300, Train Loss: 0.6728, Train Acc: 0.5385,                   Val Acc: 0.5026, Val AUC: 0.5000
# Epoch: 400, Train Loss: 0.6299, Train Acc: 0.5385,                   Val Acc: 0.5026, Val AUC: 0.5000
# Epoch: 500, Train Loss: 0.5944, Train Acc: 0.5369,                   Val Acc: 0.5026, Val AUC: 0.5000
# Epoch: 600, Train Loss: 0.5836, Train Acc: 0.5380,                   Val Acc: 0.5026, Val AUC: 0.5000
# Epoch: 700, Train Loss: 0.5653, Train Acc: 0.5374,                   Val Acc: 0.5026, Val AUC: 0.5000
# Epoch: 800, Train Loss: 0.5494, Train Acc: 0.5358,                   Val Acc: 0.5026, Val AUC: 0.5000
# Epoch: 900, Train Loss: 0.5489, Train Acc: 0.5391,                   Val Acc: 0.5026, Val AUC: 0.5000
# Epoch: 1000, Train Loss: 0.5347, Train Acc: 0.5369,                   Val Acc: 0.5026, Val AUC: 0.5000
# Test Acc: 0.5091, Test AUC: 0.4962

# %%
sim_data = exp.data_processor.get_simulate_data()
sim_data['y_pred'] = y_pred
bt = sim.backtest(sim_data)
bt.run()
# Out:
# Start                     2021-08-03 00:00...
# End                       2023-07-21 00:00...
# Duration                    717 days 00:00:00
# Exposure Time [%]                    99.59596
# Equity Final [$]                  9294.230261
# Equity Peak [$]                  10379.732699
# Return [%]                          -7.057697
# Buy & Hold Return [%]               31.778804
# Return (Ann.) [%]                   -3.657537
# Volatility (Ann.) [%]                3.449075
# Sharpe Ratio                              0.0
# Sortino Ratio                             0.0
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -10.544611
# Avg. Drawdown [%]                    -1.42682
# Max. Drawdown Duration      539 days 00:00:00
# Avg. Drawdown Duration       70 days 00:00:00
# # Trades                                  260
# Win Rate [%]                             45.0
# Best Trade [%]                       7.833849
# Worst Trade [%]                    -12.911584
# Avg. Trade [%]                       -0.29354
# Max. Trade Duration          15 days 00:00:00
# Avg. Trade Duration           4 days 00:00:00
# Profit Factor                        0.797258
# Expectancy [%]                      -0.249217
# SQN                                 -1.398489
# _strategy                          MyStrategy
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object
